# %% [markdown]
# # Merging LAP, P5V, GDP

# %% [markdown]
# ## Functions

# %%
def read_file(file_string):
    f = open(file_string, "r")
    df = []
    headers = f.readline()
    line = f.readline()
    while line:
        line = line.strip().split(",")
        df.append(line)
        line = f.readline()
    f.close()
    return df

# %%
def get_instances_in(df, country, year, col, element):
    n = 0
    for i in range(len(df)):
        if(str(country) == str(df[i][0])):
            if(str(year) == str(df[i][2])):
                n = n + (df[i][col].lower()).count(element)
    return n

# %%
def get_unique_strings(df, col):
    line = ""
    for i in range(len(df)):
        line = line + ";" + str(df[i][col])
    line = line.split(";")
    for i in range(len(line)):
        line[i] = (line[i]).strip()
        line[i] = (line[i]).lower()
    line = [string for string in line if string != ""]
    import numpy as np
    linenp = np.array(line)
    unique = np.unique(linenp)
    return unique

# %% [markdown]
# ## Read in files

# %% [markdown]
# ### Laws and Policies

# %%
lap = read_file("LAP.csv")
print(lap[0])
# Out:
# ['Energy Sector Strategy 1387-1391 (2007/8-2012/3)', 'executive', 'Afghanistan', 'AFG', '', 'Mitigation', 'Developing plans and strategies;Governance and planning;Capacity-building;Capacity-building', 'Strategy', '', 'Energy Supply', 'Energy', '25', '12', '2008', 'Law passed', '', '', '', '', '', '', '', '']

# %%
new = []

#geography , geography iso, y, type, frameworks, responses, instruments, document types, natural hazards, keywords, sectors
rel = [2, 3, 13, 1, 4, 5, 6, 7, 8, 9, 10]

for i in range(len(lap)):
    row = []
    for j in range(len(rel)):
        row.append(lap[i][rel[j]])
    new.append(row)
    
lap = new

# %%
import pandas as pd
pddf_lap = pd.DataFrame(lap, columns=['geography', 'geography iso', 'y', 'type', 'frameworks', 'responses', 'instruments',
                                       'document types', 'natural hazards', 'keywords', 'sectors'])
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pddf_lap.head(10)
# Out:
#      geography geography iso     y         type frameworks  \
# 0  Afghanistan           AFG  2008    executive
# 1  Afghanistan           AFG  2013    executive
# 2  Afghanistan           AFG  2007    executive
# 3  Afghanistan           AFG  2011    executive    Drm/Drr
# 4  Afghanistan           AFG  2009    executive
# 5  Afghanistan           AFG  2014    executive
# 6  Afghanistan           AFG  2016    executive
# 7  Afghanistan           AFG  2012  legislative
# 8  Afghanistan           AFG  2015    executive
# 9  Afghanistan           AFG  2014    executive
#
#                               responses  \
# 0                            Mitigation
# 1                            Adaptation
# 2                Adaptation; Mitigation
# 3  Adaptation; Disaster Risk Management
# 4                            Adaptation
# 5                            Adaptation
# 6                            Adaptation
# 7  Adaptation; Disaster Risk Management
# 8                            Mitigation
# 9              Disaster Risk Management
#
#                                          instruments  document types  \
# 0  Developing plans and strategies;Governance and...        Strategy
# 1  Standards and obligations;Regulation;Subsidies...          Policy
# 2         Research and development;Capacity-building          Policy
# 3  Knowledge generation;Capacity-building;Designi...            Plan
# 4                                                               Plan
# 5  Designing processes;Governance and planning;De...        Strategy
# 6  Standards and obligations;Regulation;Developin...       Programme
# 7  Creating bodies and institutions;Governance an...             Law
# 8              Taxes;Incentives;Subsidies;Incentives          Policy
# 9  Knowledge sharing and dissemination;Capacity-b...  Plan; Strategy
#
#                                      natural hazards  \
# 0
# 1
# 2
# 3  Earthquake; Flood; Glacial Melt; Drought; Wild...
# 4
# 5
# 6
# 7
# 8
# 9            Earthquake; Drought; Floods; Landslides
#
#                                        keywords  \
# 0                                 Energy Supply
# 1                     Adaptation; Energy Supply
# 2                      Research And Development
# 3                                    Adaptation
# 4                                    Adaptation
# 5                    Adaptation; Carbon Pricing
# 6                                    Adaptation
# 7                                    Adaptation
# 8  Carbon Pricing; Energy Supply; Energy Demand
# 9                      Disaster Risk Management
#
#                                              sectors
# 0                                             Energy
# 1                                             Energy
# 2                                       Economy-wide
# 3
# 4
# 5                                Environment; LULUCF
# 6  Agriculture; Energy; Environment; Residential ...
# 7                                      LULUCF; Water
# 8                             Energy; Transportation
# 9                     Disaster Risk Management (Drm)

# %% [markdown]
# ### P5V

# %%
p5v = read_file("P5V.csv")
print(p5v[0])
# Out:
# ['0', '7001800', '700', 'AFG', 'Afghanistan', '1800', '0', '', '1', '7', '-6', '-6', '', '3', '1', '1', '1', '3', '3', '1', '1', '6', '', '', '', '', '', '', '1', '1', '1800', '1', '-6', '88', '1', '', '']

# %%
new = []

for i in range(len(p5v)):
    if( int(p5v[i][5]) > 1979 and int(p5v[i][5]) < 2021): #only take 1980 - 2020
        new.append(p5v[i])
        
p5v = new

# %%
import pandas as pd
pddf_p5v = pd.DataFrame(p5v, columns=['p5', 'cyear', 'ccode', 'scode', 'country', 'year', 'flag', 'fragment', 'democ', 'autoc', 'polity',
                                         'polity2', 'durable', 'xrreg', 'xrcomp', 'xropen', 'xconst', 'parreg', 'parcomp', 'exrec',
                                         'exconst', 'polcomp', 'prior', 'emonth', 'eday', 'eyear', 'eprec', 'interim', 'bmonth', 'bday',
                                         'byear', 'bprec', 'post', 'change', 'd5', 'sf', 'regtrans'])
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pddf_p5v.head(10)
# Out:
#   p5    cyear ccode scode      country  year flag fragment democ autoc polity  \
# 0  0  7001980   700   AFG  Afghanistan  1980    0            -66   -66    -66
# 1  0  7001981   700   AFG  Afghanistan  1981    0            -66   -66    -66
# 2  0  7001982   700   AFG  Afghanistan  1982    0            -66   -66    -66
# 3  0  7001983   700   AFG  Afghanistan  1983    0            -66   -66    -66
# 4  0  7001984   700   AFG  Afghanistan  1984    0            -66   -66    -66
# 5  0  7001985   700   AFG  Afghanistan  1985    0            -66   -66    -66
# 6  0  7001986   700   AFG  Afghanistan  1986    0            -66   -66    -66
# 7  0  7001987   700   AFG  Afghanistan  1987    0            -66   -66    -66
# 8  0  7001988   700   AFG  Afghanistan  1988    0            -66   -66    -66
# 9  0  7001989   700   AFG  Afghanistan  1989    0              0     8     -8
#
#   polity2 durable xrreg xrcomp xropen xconst parreg parcomp exrec exconst  \
# 0               0   -66    -66    -66    -66    -66     -66   -66     -66
# 1               0   -66    -66    -66    -66    -66     -66   -66     -66
# 2               0   -66    -66    -66    -66    -66     -66   -66     -66
# 3               0   -66    -66    -66    -66    -66     -66   -66     -66
# 4               0   -66    -66    -66    -66    -66     -66   -66     -66
# 5               0   -66    -66    -66    -66    -66     -66   -66     -66
# 6               0   -66    -66    -66    -66    -66     -66   -66     -66
# 7               0   -66    -66    -66    -66    -66     -66   -66     -66
# 8               0   -66    -66    -66    -66    -66     -66   -66     -66
# 9      -8       0     2      1      4      2      4       1     3       2
#
#   polcomp prior emonth eday eyear eprec interim bmonth bday byear bprec post  \
# 0     -66                                   -66
# 1     -66                                   -66
# 2     -66                                   -66
# 3     -66                                   -66
# 4     -66                                   -66
# 5     -66                                   -66
# 6     -66                                   -66
# 7     -66                                   -66
# 8     -66                                   -66
# 9       1    -7      4   16  1978     3     -66      2    4  1989     1   -8
#
#   change d5 sf regtrans
# 0    -66            -66
# 1    -66            -66
# 2    -66            -66
# 3    -66            -66
# 4    -66            -66
# 5    -66            -66
# 6    -66            -66
# 7    -66            -66
# 8    -66            -66
# 9     -1  1           0

# %% [markdown]
# ### GDP

# %%
gdp = read_file("GDP.csv")
print(gdp[0])
# Out:
# ['Aruba', 'ABW', 'GDP per capita (constant 2015 US$)', 'NY.GDP.PCAP.KD', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '17231.37976', '20262.94489', '24343.25518', '27313.49536', '27884.25315', '28953.52471', '29031.74375', '29324.79206', '29989.01814', '29367.30967', '28684.56498', '29901.35929', '29857.55966', '29640.04523', '31245.72404', '29656.10401', '28051.11922', '28008.50355', '29695.49296', '29670.28769', '29743.52963', '30160.52784', '30092.73937', '26903.17135', '25857.49338', '26647.64354', '26150.63694', '27090.02617', '27011.32032', '28396.90842', '28847.81406', '29286.24932', '', '', '']

# %%
new = []
for i in range(len(gdp)):
    for j in range(len(gdp[i]) - 4):
        row = []
        row.append(gdp[i][0])            #country
        row.append(str(gdp[i][1]))       #country code
        row.append(str(1960+j))          #year
        row.append(str(gdp[i][j+4]))     #gdp
        if( int(row[2]) > 1979 and int(row[2]) < 2021): #only take 1980 - 2020
            new.append(row)
            
gdp = new

# %%
import pandas as pd
pddf_gdp = pd.DataFrame(gdp, columns=['country', 'scode', 'year', 'GDPpc'])
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pddf_gdp.head(10)
# Out:
#   country scode  year        GDPpc
# 0   Aruba   ABW  1980
# 1   Aruba   ABW  1981
# 2   Aruba   ABW  1982
# 3   Aruba   ABW  1983
# 4   Aruba   ABW  1984
# 5   Aruba   ABW  1985
# 6   Aruba   ABW  1986  17231.37976
# 7   Aruba   ABW  1987  20262.94489
# 8   Aruba   ABW  1988  24343.25518
# 9   Aruba   ABW  1989  27313.49536

# %% [markdown]
# ## Creating new LAP table

# %%
#new columns from splitting lap columns

ls_uniques = []
for i in range(len(lap[0])-3):
    ls_uniques.append(get_unique_strings(lap,i+3))

# %%
#get_instances_in(df, country, year, col, element)
print(get_instances_in(lap, "Afghanistan", 2014, 3, "executive"))
# Out:
# 2

# %%
ls_none = []
for i in range(len(p5v[0])-3):
    ls_none.append('')
print(ls_none)
# Out:
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']

# %%
new = []

for i in range(len(gdp)):
    row = []
    row = gdp[i]
    
    match = False
    for j in range(len(p5v)):
        if(p5v[j][3] == gdp[i][1] and p5v[j][5] == gdp[i][2]):
            match = True
            row = row + p5v[j][:3] + p5v[j][6:] 
    if(match == False):
        row = row + ls_none
        
    for j in range(len(ls_uniques)):
        for k in range(len(ls_uniques[j])):
            row.append(get_instances_in(lap, gdp[i][0], gdp[i][2], j+3, ls_uniques[j][k]))
    new.append(row)
    
    if(i % 100 == 0):
        print(str(round(i/(len(gdp))*100,3))+"%")
# Out:
# 0.0%
# 0.917%
# 1.834%
# 2.751%
# 3.668%
# 4.585%
# 5.502%
# 6.418%
# 7.335%
# 8.252%
# 9.169%
# 10.086%
# 11.003%
# 11.92%
# 12.837%
# 13.754%
# 14.671%
# 15.588%
# 16.505%
# 17.422%
# 18.339%
# 19.255%
# 20.172%
# 21.089%
# 22.006%
# 22.923%
# 23.84%
# 24.757%
# 25.674%
# 26.591%
# 27.508%
# 28.425%
# 29.342%
# 30.259%
# 31.175%
# 32.092%
# 33.009%
# 33.926%
# 34.843%
# 35.76%
# 36.677%
# 37.594%
# 38.511%
# 39.428%
# 40.345%
# 41.262%
# 42.179%
# 43.096%
# 44.012%
# 44.929%
# 45.846%
# 46.763%
# 47.68%
# 48.597%
# 49.514%
# 50.431%
# 51.348%
# 52.265%
# 53.182%
# 54.099%
# 55.016%
# 55.933%
# 56.849%
# 57.766%
# 58.683%
# 59.6%
# 60.517%
# 61.434%
# 62.351%
# 63.268%
# 64.185%
# 65.102%
# 66.019%
# 66.936%
# 67.853%
# 68.769%
# 69.686%
# 70.603%
# 71.52%
# 72.437%
# 73.354%
# 74.271%
# 75.188%
# 76.105%
# 77.022%
# 77.939%
# 78.856%
# 79.773%
# 80.69%
# 81.606%
# 82.523%
# 83.44%
# 84.357%
# 85.274%
# 86.191%
# 87.108%
# 88.025%
# 88.942%
# 89.859%
# 90.776%
# 91.693%
# 92.61%
# 93.526%
# 94.443%
# 95.36%
# 96.277%
# 97.194%
# 98.111%
# 99.028%
# 99.945%

# %%
lap_headers = []
for i in range(len(ls_uniques)):
    for j in range(len(ls_uniques[i])):
        lap_headers.append(ls_uniques[i][j])
        
p5v_headers=['p5', 'cyear', 'ccode', 'flag', 'fragment', 'democ', 'autoc', 'polity',
             'polity2', 'durable', 'xrreg', 'xrcomp', 'xropen', 'xconst', 'parreg', 'parcomp', 'exrec',
             'exconst', 'polcomp', 'prior', 'emonth', 'eday', 'eyear', 'eprec', 'interim', 'bmonth', 'bday',
             'byear', 'bprec', 'post', 'change', 'd5', 'sf', 'regtrans']

# %%
import pandas as pd
pddf_new = pd.DataFrame(new, columns=[['country', 'scode', 'year', 'GDPpc'] + p5v_headers + lap_headers]) 

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pddf_new.head(10)

# %% [markdown]
# ## Download full table

# %%
pddf_new.to_csv('gdp_p5v_lap.csv', index=False)
